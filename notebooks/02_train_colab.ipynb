# %%
# !git clone https://github.com/your-repo/meter-ocr-crnn.git
# %cd meter-ocr-crnn
# !pip install -r requirements.txt

# %%
from tools.train import main
main("configs/crnn_mobilenet_ctc.yaml")
